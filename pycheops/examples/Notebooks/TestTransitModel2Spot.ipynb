# %%
# %matplotlib inline
import lightkurve as lk
from pycheops.models import TransitModel2Spot
import numpy as np
import matplotlib.pyplot as plt

# %%
# See Deming et al. Fig. 2
BJD_T0 =  2454605.89155  
P = 4.8878018
W = 0.02

ORBIT = 74

# %%
# Using SAP_FLUX data because PDCSAP_FLUX data show wierd ripples of ~hour timescale.
lc = lk.search_lightcurve('HAT-P-11',quarter=1,exptime=60).download(flux_column='sap_flux').remove_nans()
tmid = BJD_T0 - 2454833 + P*ORBIT
m = abs(lc.time.value - tmid) < 0.1
lc = lc[m]
lc /= np.median(lc.flux.value[abs(lc.time.value - tmid) > W*P/2])
#ax = lc.scatter()
#ax.axvline(tmid+W*P/2,c='k',alpha=0.5,ls='--')
#ax.axvline(tmid-W*P/2,c='k',alpha=0.5,ls='--')
#ax.axhline(1,c='k',alpha=0.5);

# %%
model = TransitModel2Spot()
pars = model.make_params(T_0 = 0, P=P, D=0.004, W=W, 
                         t1 = -0.014, w1 = 0.004, t2 = 0.02, w2 = 0.004)
pars['T_0'].min = -0.1
pars['T_0'].max = +0.1
pars['P'].vary = False
pars['h_1'].vary = True
pars['s2'].vary = False
pars['f2'].vary = False

time = np.array(lc.time.value) - tmid
flux = np.array(lc.flux.value)
flux_err = np.array(lc.flux_err.value)*np.sqrt(1.318)   # Errors scaled to get reduced chi-squared =~ 1
result = model.fit(flux, t=time, params=pars, weights=1/flux_err)

# %%
result.plot_fit(xlabel='Time since mid-transit [days]', ylabel='Flux', data_kws={'ms':2});

# %%
result
# Out:
# <h2>Fit Result</h2> <p>Model: Model(_transit_func_2spot)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>306</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>293</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>13</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 279.228318</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 0.99724399</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'> 11.8941545</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'> 59.7363984</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'>-269287.138</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:left'>vary</th><th style='text-align:right'>expression</th></tr><tr><td style='text-align:left'>T_0</td><td style='text-align:left'>-6.2856e-06</td><td style='text-align:left'> 4.8682e-05</td><td style='text-align:left'>(774.50%)</td><td style='text-align:left'>0.0</td><td style='text-align:left'>-0.10000000</td><td style='text-align:left'> 0.10000000</td><td style='text-align:left'>True</td><td style='text-align:right'></td></tr><tr><td style='text-align:left'>P</td><td style='text-align:left'> 4.88780180</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>4.8878018</td><td style='text-align:left'> 1.0000e-15</td><td style='text-align:left'>        inf</td><td style='text-align:left'>False</td><td style='text-align:right'></td></tr><tr><td style='text-align:left'>D</td><td style='text-align:left'> 0.00345147</td><td style='text-align:left'> 6.1121e-05</td><td style='text-align:left'>(1.77%)</td><td style='text-align:left'>0.004</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'> 0.25000000</td><td style='text-align:left'>True</td><td style='text-align:right'></td></tr><tr><td style='text-align:left'>W</td><td style='text-align:left'> 0.02017211</td><td style='text-align:left'> 6.6259e-05</td><td style='text-align:left'>(0.33%)</td><td style='text-align:left'>0.02</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'> 0.30000000</td><td style='text-align:left'>True</td><td style='text-align:right'></td></tr><tr><td style='text-align:left'>b</td><td style='text-align:left'> 0.25494110</td><td style='text-align:left'> 0.10022907</td><td style='text-align:left'>(39.31%)</td><td style='text-align:left'>0.3</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'> 1.00000000</td><td style='text-align:left'>True</td><td style='text-align:right'></td></tr><tr><td style='text-align:left'>f_c</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'></td><td style='text-align:left'>0</td><td style='text-align:left'>-1.00000000</td><td style='text-align:left'> 1.00000000</td><td style='text-align:left'>False</td><td style='text-align:right'></td></tr><tr><td style='text-align:left'>f_s</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'></td><td style='text-align:left'>0</td><td style='text-align:left'>-1.00000000</td><td style='text-align:left'> 1.00000000</td><td style='text-align:left'>False</td><td s ...
