# %% [markdown]
# To speed-up setup and avoid memory limits we only display 1-in-4 images

# %%
# %pylab notebook
from pycheops import Dataset
from tqdm import tqdm_notebook as tqdm
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ds=Dataset.from_test_data('DP-079', target='HD97658')
cube = ds.get_imagettes()
cube1in4 = (cube[::4,:,:])
# Out:
# ...
# Writing Imagette data to .tgz file...
# Writing Lightcurve data to .tgz file...
# .. CH_PR900048_TG001501_TU2020-04-03T04-11-52_SCI_COR_Lightcurve-DEFAULT_V0000.fits - done
# .. CH_PR900048_TG001501_TU2020-04-03T04-11-52_SCI_COR_Lightcurve-OPTIMAL_V0000.fits - done
# .. CH_PR900048_TG001501_TU2020-04-03T04-11-52_SCI_COR_Lightcurve-RINF_V0000.fits - done
# .. CH_PR900048_TG001501_TU2020-04-03T04-11-52_SCI_COR_Lightcurve-RSUP_V0000.fits - done
# Found archive tgzfile /Users/pflm/pycheops_data/CH_PR900048_TG001501_V0000.tgz
# Creating dataset file list
#  PI name     : CHEOPSim
#  OBS ID      : 7649
#  Target      : HD97658
#  Coordinates : 11:14:33.16 +25:42:37.4
# Extracting imagette data from  /Users/pflm/pycheops_data/CH_PR900048_TG001501_V0000.tgz
# Saved imagette data to  /Users/pflm/pycheops_data/CH_PR900048_TG001501_V0000-Imagette.fits

# %%
import matplotlib.animation as animation
from IPython.display import HTML
fig = plt.figure()
ims = []
for i in tqdm(range(len(cube1in4))):
    im = plt.imshow(cube1in4[i,:,:],interpolation='nearest',cmap='gist_heat', animated=True)
    ims.append([im])
anim = animation.ArtistAnimation(fig, ims, interval=100, blit=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %% [markdown]
# &copy; Pierre Maxted, Keele University, 2019
