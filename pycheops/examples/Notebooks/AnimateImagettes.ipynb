# %% [markdown]
# To speed-up setup and avoid memory limits we only display 1-in-4 images

# %%
# %pylab notebook
from pycheops import dataset
from tqdm import tqdm_notebook as tqdm
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ds=dataset('PR300006_TG000102')
cube, hdr, meta = ds.get_imagettes()
cube1in4 = (cube[::4,:,:])
# Out:
# Found archive tgzfile /Users/pflm/pycheops_data/PR300006_TG000102.tgz
# /Users/pflm/anaconda/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import matplotlib.animation as animation
from IPython.display import HTML
fig = plt.figure()
ims = []
for i in tqdm(range(len(cube1in4))):
    im = plt.imshow(cube1in4[i,:,:],interpolation='nearest',cmap='gist_heat', animated=True)
    ims.append([im])
anim = animation.ArtistAnimation(fig, ims, interval=100, blit=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# HBox(children=(IntProgress(value=0, max=817), HTML(value='')))

# %% [markdown]
# &copy; Pierre Maxted, Keele University, 2019
