# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from pycheops.funcs import massradius
from uncertainties import ufloat
from uncertainties.umath import sin as usin

# %%
# pi Men
m_star = (1.094, 0.039)
r_star = (1.10, 0.023)
k = (0.01703, 0.00024)
aR =  (13.38, 0.26)
sini = usin(ufloat(87.456,0.080)*np.pi/180)
P = (6.2679, 0.00046)
ecc = 0 
K = (1.58, 0.27)

# %%
r,fig=massradius(m_star=m_star, r_star=r_star, 
                 k=k, ecc=ecc, aR=aR, K=K, sini=sini,P=P, 
                 plot=True, jovian=True, return_samples=True,
                 err_kws={'c':'r','capsize':3,'fmt':'o','ms':4},
                 lab_kws={'fontsize':14,'color':'g'},logmass=1,
                 tick_kws={'labelsize':12},
                 zeng_models=['R100H2O','Rrock','R25H2O','R50H2O'],
                 show_legend=True, legend_kws={'fancybox':True})
# Out:
#     m_star   =      1.094 +/-      0.039 (    -0.039,    +0.039) M_Sun
#     r_star   =      1.100 +/-      0.023 (    -0.023,    +0.023) R_Sun
#     e        =       0.00 +/-       0.00 (     -0.00,     +0.00)
#     r_p      =     0.1864 +/-     0.0047 (   -0.0047,   +0.0047) R_Jup
#     m_p      =     0.0152 +/-     0.0026 (   -0.0026,   +0.0026) M_Jup
#     q        =  0.0000133 +/-  0.0000023 (-0.0000023,+0.0000023)
#     a        =      14.74 +/-       0.17 (     -0.18,     +0.17) R_Sun
#     a        =    0.06855 +/-    0.00081 (  -0.00082,  +0.00080) au
#     rho_star =      0.818 +/-      0.048 (    -0.047,    +0.048) rho_Sun
#     g_p      =       11.3 +/-        2.0 (      -2.0,      +2.0) m.s-2
#     log g_p  =      3.053 +/-      0.078 (    -0.083,    +0.072) [cgs]
#     rho_p    =       2.34 +/-       0.43 (     -0.42,     +0.44) rho_Jup
#     rho_p    =       3.10 +/-       0.58 (     -0.56,     +0.59) [g.cm-3]

# %% [markdown]
# &copy;2024 Pierre Maxted, Keele Universty
